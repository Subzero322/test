# %% [markdown]
# ## Главные задачи, которые должен выполнять скрипт:
#
# - Извлекать реплики с приветствием – где менеджер поздоровался.
# - Извлекать реплики, где менеджер представил себя.
# - Извлекать имя менеджера.
# - Извлекать название компании.
# - Извлекать реплики, где менеджер попрощался.
# - Проверять требование к менеджеру: «В каждом диалоге обязательно необходимо поздороваться и попрощаться с клиентом»
#
# ### **Рекомендации**:
# Сделать локальную копию файла test_data.csv, в исходнике никакие данные не менять!
# Можно создать дополнительное поле в таблице test_data.csv, куда будет сохраняться результат парсинга – например, напротив реплики в столбце “insight” можно ставить флаг того, что эта реплика с приветствием greeting=True.
# Для выполнения задачи можно использовать любые библиотеки и NLP модели.
# Попробуйте учесть возможные синонимичные выражения, которые могут помочь с извлечением данных сущностей.
# Попробуйте использовать другие методы извлечения данных сущностей.

# %%
import pandas as pd
import numpy as np
import re
import spacy
import string
from nltk.stem import PorterStemmer
from spacy.lang.en.stop_words import STOP_WORDS
from spacy.lang.en import English
from spacy.lang.ru.stop_words import STOP_WORDS
import nltk
from nltk.stem import PorterStemmer
from nltk import word_tokenize
from spacy.matcher import Matcher

from nltk.tokenize import word_tokenize, sent_tokenize

# %%
#supress warnings
import warnings
warnings.filterwarnings('ignore')

# %%
from natasha import (
    Segmenter,
    MorphVocab,

    NewsEmbedding,
    NewsMorphTagger,
    NewsSyntaxParser,
    NewsNERTagger,

    PER,
    NamesExtractor,
    DatesExtractor,
    MoneyExtractor,
    AddrExtractor,

    Doc
)

# %%
import ssl # для проверки подключения к интернету

# %%
try:
    _create_unverified_https_context = ssl._create_unverified_context
except AttributeError:
    pass
else:
    ssl._create_default_https_context = _create_unverified_https_context

# nltk.download()

# %%
import nltk
nltk.download('punkt')
nltk.download('stopwords')
stop_words_ru = nltk.corpus.stopwords.words("russian")
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\maxal\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\maxal\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
stop_words_ru = nltk.corpus.stopwords.words("russian")

# %%
# Загрузка данных
data = pd.read_csv('test_data.csv')
data.head()
# Out:
#    dlg_id  line_n     role                                               text
# 0       0       0   client                                               Алло
# 1       0       1  manager                                  Алло здравствуйте
# 2       0       2   client                                        Добрый день
# 3       0       3  manager  Меня зовут ангелина компания диджитал бизнес з...
# 4       0       4   client                                                Ага

# %%
# Можно создать дополнительное поле в таблице test_data.csv, куда будет сохраняться результат парсинга – например, напротив реплики в столбце “insight” можно ставить флаг того, что эта реплика с приветствием greeting=True.

# %%
data['greeting'] = False
data['introduction'] = False
data['manager_name'] = False
data['company_name'] = False
data['goodbye'] = False

# %%
data.head()
# Out:
#    dlg_id  line_n     role                                               text  \
# 0       0       0   client                                               Алло
# 1       0       1  manager                                  Алло здравствуйте
# 2       0       2   client                                        Добрый день
# 3       0       3  manager  Меня зовут ангелина компания диджитал бизнес з...
# 4       0       4   client                                                Ага
#
#    greeting  introduction  manager_name  company_name  goodbye
# 0     False         False         False         False    False
# 1     False         False         False         False    False
# 2     False         False         False         False    False
# 3     False         False         False         False    False
# 4     False         False         False         False    False

# %%
txt = data['text']

# %%
#!python -m spacy download ru_core_news_sm

# %%
# Загрузка модели для обработки текста

# %%
nlp = spacy.load("ru_core_news_sm")

# %%
# нормализация данных текстовых полей

# %%
#my_stop = {'a'}
stop_words = stop_words_ru
punctuations = string.punctuation

def spacy_tokenizer(sentence):
    # Create token object, which is used to create documents with linguistic annotations.
    # Создадим токены, которые будем использовать для создания документов с лингвистическими аннотациями
    # грубо говоря мы создаём токены без мусорных слов
    
    mytokens = nlp(sentence)
    porter = PorterStemmer()

    # лематизация
    mytokens = [ word.lemma_.lower().strip() if word.lemma_ != "-PRON-" else word.lower_ for word in mytokens ]

    # удаляем стоп слова и пунктуацию
    mytokens = [ word for word in mytokens if word not in stop_words and word not in punctuations ]

    return mytokens

# %%
# Применение токенизатора к данным

# %%
data['tokens']=data['text'].apply(spacy_tokenizer)

# %%
data.head()
# Out:
#    dlg_id  line_n     role                                               text  \
# 0       0       0   client                                               Алло
# 1       0       1  manager                                  Алло здравствуйте
# 2       0       2   client                                        Добрый день
# 3       0       3  manager  Меня зовут ангелина компания диджитал бизнес з...
# 4       0       4   client                                                Ага
#
#    greeting  introduction  manager_name  company_name  goodbye  \
# 0     False         False         False         False    False
# 1     False         False         False         False    False
# 2     False         False         False         False    False
# 3     False         False         False         False    False
# 4     False         False         False         False    False
#
#                                               tokens
# 0                                             [алло]
# 1                              [алло, здравствовать]
# 2                                     [добрый, день]
# 3  [звать, ангелина, компания, диджитал, бизнес, ...
# 4                                              [ага]

# %%
#соеденим dataframe с текстовыми полями в одну строку
data['text_normalized'] = data['tokens'].apply(lambda x: ' '.join(x))

# %%
text_for_world_cloud = sum(data['tokens'].tolist(), [])

# %%
text_for_world_cloud
# Out:
# ['алло',
#  'алло',
#  'здравствовать',
#  'добрый',
#  'день',
#  'звать',
#  'ангелина',
#  'компания',
#  'диджитал',
#  'бизнес',
#  'звоним',
#  'повод',
#  'продление',
#  'лицензия',
#  'серый',
#  'скоро',
#  'срок',
#  'заканчиваться',
#  'ага',
#  'угу',
#  'возможный',
#  'рассмотреть',
#  'другие',
#  'вариант',
#  'видеть',
#  'это',
#  'хороший',
#  'практика',
#  'сравнивать',
#  'работать',
#  'компания',
#  'которая',
#  'нам',
#  'подливать',
#  'поэтому',
#  'спасибо',
#  'огромный',
#  'момент',
#  'работать',
#  'устраивать',
#  'сопровождение',
#  'поэтому',
#  'угу',
#  'обращать',
#  'внимание',
#  'выбор',
#  'выбор',
#  'обращать',
#  'внимание',
#  'дома',
#  'выбрать',
#  'приоритет',
#  'поэтому',
#  'тип',
#  'параметр',
#  'выбор',
#  'выбор',
#  'история',
#  'сотрудничество',
#  'которая',
#  'важный',
#  'смотреть',
#  '1',
#  'звоните',
#  'работать',
#  'давно',
#  'почему',
#  'звоните',
#  'течение',
#  'свой',
#  'время',
#  'работать',
#  'срок',
#  'заканчиваться',
#  'поэтому',
#  'набрать',
#  'ко',
#  'всему',
#  'совершенно',
#  'верный',
#  'делать',
#  '50',
#  'компания',
#  'которые',
#  'звонить',
#  'спрашивать',
#  'продвигать',
#  'продлевать',
#  'просто',
#  'каждый',
#  'удивляться',
#  'почему',
#  'позвонить',
#  'время',
#  'хирам',
#  'работать',
#  'хотеть',
#  'заполучить',
#  'следующий',
#  'клиент',
#  'сделать',
#  '3',
#  'звонок',
#  'следующий',
#  'период',
#  'спросить',
#  'мочь',
#  'проведите',
#  'аудист',
#  'сделать',
#  'незначительный',
#  'бесплатный',
#  'показать',
#  'свой',
#  'компетентность',
#  'выбирать',
#  'параметр',
#  'рассказывать',
#  'человек',
#  'который',
#  '18',
#  'год',
#  'работать',
#  'пролажен',
#  'рассказать',
#  'нужный',
#  'угодно',
#  'отработать',
#  'возражение',
#  'предложить',
#  'услуга',
#  'выгодный',
#  'месяц',
#  '2',
#  '3',
#  'угодно',
#  'лояльность',
#  'спрашиваться',
#  '2',
#  'месяц',
#  'показывать',
#  'показывать',
#  'работать',
#  'ваш',
#  'сфера',
#  'работать',
#  'самой',
#  'сфера',
#  'звонить',
#  'последний',
#  'момент',
#  'предложение',
#  'продлить',
#  'компания',
#  'которой',
#  'работать',
#  'поэтому',
#  'просто',
#  'обратить',
#  'внимание',
#  'пользоваться',
#  'виджет',
#  'вами',
#  'сотрудничать',
#  'недостаточно',
#  'хороший',
#  'качественный',
#  'услуга',
#  'исключительно',
#  'рассказывать',
#  'очень',
#  'ага',
#  '19',
#  'являться',
#  'хороший',
#  'идти',
#  'бесплатно',
#  'слушать',
#  'очень',
#  'сложный',
#  'сказать',
#  'виджет',
#  'достаточно',
#  'ага',
#  'настроены',
#  'подключить',
#  'разный',
#  'компания',
#  'поэтому',
#  'мочь',
#  'сказать',
#  'просить',
#  'прощение',
#  'просто',
#  'наверное',
#  'очень',
#  'действительно',
#  'это',
#  'сказать',
#  'э',
#  'стопа',
#  'самый',
#  'полтора',
#  'год',
#  'весь',
#  'время',
#  'действительно',
#  'удивлять',
#  'просто',
#  'извинить',
#  'свой',
#  'подход',
#  'немножко',
#  'целое',
#  'компания',
#  'давать',
#  'просто',
#  'хороший',
#  'качественный',
#  'обратный',
#  'связь',
#  'которую',
#  'возможный',
#  'особо',
#  'давать',
#  'контакт',
#  'клиент',
#  'вне',
#  'формат',
#  'завершение',
#  'лицензия',
#  'индивидуальный',
#  'поэтому',
#  'сотрудничать',
#  'например',
#  'справляться',
#  'сравнивать',
#  'звонить',
#  'смотреть',
#  'история',
#  'годичный',
#  'работа',
#  'компания',
#  'которая',
#  'принцип',
#  'устраивать',
#  'которая',
#  'контакт',
#  'сопровождение',
#  'предлагать',
#  'нарекание',
#  'это',
#  'хороший',
#  'компания',
#  '110',
#  'компания',
#  'которые',
#  'понимать',
#  'просто',
#  'подумать',
#  'человек',
#  'клиент',
#  'которым',
#  'звоните',
#  'должный',
#  'изменить',
#  'свой',
#  'решение',
#  'отношение',
#  'ваш',
#  'компания',
#  'годичный',
#  'история',
#  'работа',
#  'либо',
#  'нарекание',
#  'менеджер',
#  'которые',
#  'звонить',
#  'предлагать',
#  'пробить',
#  'причина',
#  'должный',
#  'принять',
#  'решение',
#  'ваш',
#  'польза',
#  'переключить',
#  'просто',
#  'услышать',
#  'спасибо',
#  'рекомендация',
#  'штуковина',
#  'получаться',
#  'конверсия',
#  'база',
#  'которую',
#  'обзванивать',
#  'скорее',
#  'получить',
#  'контракт',
#  'человек',
#  'которых',
#  'либо',
#  'печальный',
#  'сотрудничество',
#  'предыдущий',
#  'компания',
#  'либо',
#  'вообще',
#  'нету',
#  'факт',
#  'мочь',
#  'получить',
#  'допустить',
#  'контакт',
#  'делать',
#  'аудит',
#  'это',
#  'вообще',
#  'копейка',
#  'время',
#  'давать',
#  'рекомендация',
#  'рекомендация',
#  'аудит',
#  'дать',
#  'реально',
#  'польза',
#  'компания',
#  'которая',
#  'работать',
#  'видеть',
#  'это',
#  'простой',
#  'понимать',
#  'дело',
#  'основный',
#  'месяц',
#  'простой',
#  'шаг',
#  'который',
#  'принцип',
#  'мочь',
#  'делать',
#  'э',
#  'понимать',
#  'почему',
#  'никто',
#  'делать',
#  'алло',
#  'честно',
#  'просто',
#  'забивать',
#  'счёт',
#  'счёт',
#  'это',
#  'компания',
#  'которая',
#  'звонить',
#  'решать',
#  'договор',
#  'месяц',
#  'завершение',
#  'звонить',
#  'компания',
#  '15',
#  'честно',
#  'это',
#  'вызывать',
#  'понимать',
#  'хотеть',
#  'услышать',
#  'исключительно',
#  'случай',
#  'ага',
#  'необходимый',
#  'обзванивать',
#  'ага',
#  'данную',
#  'информация',
#  'зафиксирую',
#  'перёд',
#  'будем',
#  'иметь',
#  'ввиду',
#  'просто',
#  'подумать',
#  'подумать',
#  'ваш',
#  'команда',
#  'мочь',
#  'это',
#  'звонок',
#  'месяц',
#  'окончание',
#  'интересный',
#  'конверсия',
#  'допустить',
#  '1000',
#  'человек',
#  'которые',
#  'обзванивать',
#  'сколько',
#  'человек',
#  'соглашаться',
#  'виджеты',
#  'бесплатно',
#  'видно',
#  'ваш',
#  'это',
#  'весь',
#  'мочь',
#  'использовать',
#  'ваш',
#  'польза',
#  'честно',
#  'понимать',
#  'продажа',
#  'весь',
#  'работать',
#  'отдельно',
#  'никто',
#  'спасибо',
#  'огромный',
#  'спасибо',
#  'большой',
#  'обратный',
#  'связь',
#  'угу',
#  'хороший',
#  'свидание',
#  'здравствовать',
#  'заканчиваться',
#  'алло',
#  'здравствовать',
#  'звать',
#  'ангелина',
#  'компания',
#  'диджитал',
#  'бизнес',
#  'звоню',
#  'повод',
#  'продление',
#  'сесть',
#  'обратить',
#  'внимание',
#  'срок',
#  'заканчиваться',
#  'заканчиваться',
#  '25',
#  'февраль',
#  'полгода',
#  'минимальный',
#  '25',
#  'февраль',
#  'минимальный',
#  'срок',
#  'продление',
#  '8',
#  'базовый',
#  'правильно',
#  'секунда',
#  '6',
#  'месяц',
#  'сколько',
#  'стоить',
#  'текущий',
#  'количество',
#  'пользователь',
#  '8',
#  'пользователь',
#  'указать',
#  'правильно',
#  'знать',
#  'знать',
#  'посмотреть',
#  'угу',
#  '1',
#  '2',
#  '3',
#  '4',
#  '5',
#  'вообще',
#  '5',
#  'активный',
#  'пока',
#  'наверное',
#  'секунда',
#  '1',
#  '2',
#  '3',
#  '65',
#  '1',
#  '2',
#  '3',
#  '4',
#  '5',
#  'правильно',
#  'допустить',
#  '6',
#  '6',
#  'месяц',
#  '6',
#  'человек',
#  'наш',
#  'тариф',
#  'базовый',
#  '6',
#  'месяц',
#  'это',
#  '17964',
#  'р',
#  '6',
#  'пользователь',
#  'сказать',
#  'пожалуйста',
#  '17000',
#  '17964',
#  '564',
#  'р',
#  'вопрос',
#  'это',
#  'допустить',
#  'сказать',
#  '8',
#  'сделать',
#  'сделать',
#  'расчёт',
#  '3',
#  'пользователь',
#  'продлить',
#  'самым',
#  'просто',
#  'нужный',
#  'зайти',
#  'настройка',
#  'серым',
#  'убрать',
#  'пользователь',
#  'это',
#  'написать',
#  'техподдержка',
#  'маш',
#  'убрать',
#  'подтвердить',
#  'алло',
#  'вверху',
#  'настройка',
#  'знать',
#  'прямо',
#  'сказать',
#  'пожалуйста',
#  'пользователь',
#  'зайти',
#  'секунду',
#  'фильтр',
#  'раздел',
#  'админ',
#  'нужный',
#  'туда',
#  'зайти',
#  'количество',
#  'пользователь',
#  'активировать',
#  'угу',
#  'весь',
#  'весь',
#  'весь',
#  'активный',
#  'пользователь',
#  'активный',
#  'пользователь',
#  '5',
#  'пользователь',
#  'проверю',
#  'ваш',
#  'партнёрский',
#  'кабинет',
#  '1',
#  'секунда',
#  '1',
#  '2',
#  '3',
#  'кстати',
#  'также',
#  '5',
#  '5',
#  'пользователь',
#  '783',
#  '67',
#  '02',
#  'очень',
#  'странно',
#  'просто',
#  'указать',
#  '8',
#  'мочь',
#  'это',
#  'старый',
#  'информация',
#  'обновить',
#  'мочь',
#  'назвать',
#  'ваш',
#  'номер',
#  'аккаунт',
#  '783',
#  '67',
#  '02',
#  'правильно',
#  'угу',
#  '1',
#  'секунда',
#  'посмотреть',
#  'ваш',
#  'технический',
#  'кабинет',
#  'партнёрский',
#  '5',
#  'пользователь',
#  'правильно',
#  'обновить',
#  'информация',
#  'ничто',
#  'нужный',
#  'делать',
#  'просто',
#  'посылаю',
#  'счёт',
#  '25',
#  'февраль',
#  'весь',
#  'стандартный',
#  '25',
#  'февраль',
#  'заканчиваться',
#  'угу',
#  'подумаю',
#  'дальше',
#  'вами',
#  'свяжусь',
#  'дальше',
#  'угу',
#  'информация',
#  'продублирую',
#  'ознакомиться',
#  'сравнение',
#  'сказать',
#  'ватсап',
#  'например',
#  'мочь',
#  'почта',
#  'давать',
#  'почта',
#  'проверить',
#  'инфо',
#  'собачка',
#  'эра',
#  'чёрточка',
#  '3',
#  'дэ',
#  'точка',
#  'ру',
#  'правильно',
#  'самое',
#  'вместо',
#  'инфо',
#  'денис',
#  'дэ',
#  'е',
#  'эн',
#  'угу',
#  'точка',
#  'угу',
#  'видеть',
#  'почта',
#  'исправить',
#  'будем',
#  'ждать',
#  'ответ',
#  'весь',
#  'хороший',
#  'свидание',
#  'алло',
#  'здравствовать',
#  'алло',
#  'здравствовать',
#  'звать',
#  'ангелина',
#  'компания',
#  'диджитал',
#  'бизнес',
#  'звоню',
#  'повод',
#  'продление',
#  'лицензия',
#  'мастер',
#  'вами',
#  'сотрудничать',
#  'видео',
#  'отправлять',
#  'решить',
#  'набрать',
#  'разговаривать',
#  'удобный',
#  'удобный',
#  'говорить',
#  'рассказать',
#  'угу',
#  'хороший',
#  'подсказать',
#  'критерий',
#  'выбирать',
#  'партнёр',
#  'мочь',
#  'подготовить',
#  'предложение',
#  'цена',
#  'индексация',
#  'угу',
#  'понять',
#  'стоимость',
#  'везде',
#  'одинаковый',
#  'официальный',
#  'партнёр',
#  'цена',
#  'одинаковая',
#  'поэтому',
#  'мочь',
#  'сказать',
#  'преимущество',
#  'преимущество',
#  '20',
#  'виджет',
#  'идти',
#  'бесплатно',
#  'идти',
#  'кэшбэк',
#  '20',
#  'сумма',
#  'возвращаться',
#  'мочь',
#  'ваш',
#  'компания',
#  'называться',
#  'диджитал',
#  'бизнес',
#  'это',
#  'бизнес',
#  'север',
#  'ага',
#  'видеть',
#  'говорить',
#  'ватсап',
#  'предложение',
#  'угу',
#  'смотреть',
#  'счёт',
#  'кэшбэка',
#  'кэшбэк',
#  '20',
#  'сумма',
#  'мочь',
#  'например',
#  'приобрести',
#  'бизнес',
#  'процесс',
#  'который',
#  'актуальный',
#  'именно',
#  'ваш',
#  'бизнес',
#  'например',
#  'автоматизация',
#  'воронка',
#  'либо',
#  'контроль',
#  'например',
#  'отказ',
#  'подойти',
#  'это',
#  'наш',
#  'аналитик',
#  'подобрать',
#  'актуально',
#  'поэтому',
#  'хотеть',
#  'предложить',
#  'встреча',
#  '15',
#  '20',
#  'минута',
#  'будут',
#  'окошки',
#  'например',
#  'следующий',
#  'неделя',
#  'найти',
#  'наш',
#  'сайт',
#  'подсветка',
#  'сделка',
#  'угу',
#  'значить',
#  'писать',
#  'подсказать',
#  'нужный',
#  'мочь',
#  'подготовить',
#  'индивидуальный',
#  'предложение',
#  'нам',
#  'нужный',
#  'нам',
#  'нужный',
#  'интеграция',
#  'ватсапа',
#  'угу',
#  'угу',
#  'нам',
#  'нужный',
#  'удаление',
#  'дубль',
#  'нам',
#  'нужный',
#  'виджет',
#  'который',
#  'точно',
#  'сказать',
#  'списываться',
#  'нам',
#  'нужный',
#  'виджет',
#  'который',
#  'сделать',
#  'обязательно',
#  'несколько',
#  'группировка',
#  'поле',
#  'грузируется',
#  'делать',
#  'обязательно',
#  'выделение',
#  'диск',
#  'угу',
#  'насчет',
#  'выделение',
#  'подсветка',
#  'это',
#  'процент',
#  'насчет',
#  'интеграция',
#  'реализовать',
#  'приобретать',
#  'интеграция',
#  'мочь',
#  'оплатить',
#  'например',
#  'кэшбэком',
#  'пока',
#  'угу',
#  'понять',
#  'кэшбэка',
#  '20',
#  'идти',
#  'сумма',
#  'которую',
#  'оплачивать',
#  'мочь',
#  'помочь',
#  'подскажете',
#  'коммерческий',
#  'ватсап',
#  'почта',
#  'мочь',
#  'скинуть',
#  'коммерческий',
#  'угу',
#  'почта',
#  'подключится',
#  'это',
#  'давать',
#  'проверить',
#  'смотреть',
#  'просто',
#  '2',
#  'почта',
#  'почта',
#  'почта',
#  'меньше',
#  'сапаров',
#  'собачка',
#  'астана',
#  'собачка',
#  'ираклас',
#  'точка',
#  'кз',
#  'нету',
#  'жесупов',
#  'собачка',
#  'аэропорт',
#  'угу',
#  'написать',
#  'новый',
#  'перепутать',
#  'оставлю',
#  'ватсап',
#  'счёт',
#  'время',
#  'сориентировали',
#  'следующий',
#  'неделя',
#  'созвониться',
#  'бизнес',
#  'аналитик',
#  'угу',
#  'неделя',
#  'давать',
#  'среда',
#  'решить',
#  'угу',
#  'любой',
#  'время',
#  'любой',
#  'время',
#  'аналитик',
#  'вопрос',
#  'написать',
#  'написать',
#  'свой',
#  'окошки',
#  'ватсап',
#  'угу',
#  'угу',
#  'напишу',
#  'угу',
#  'отправить',
#  'звоните',
#  'следующий',
#  'неделя',
#  'угу',
#  'хороший',
#  'добрый',
#  'день',
#  'алло',
#  'дмитрий',
#  'добрый',
#  'день',
#  'добрый',
#  'максим',
#  'звать',
#  'компания',
#  'китобизнес',
#  'удобный',
#  'говорить',
#  'удобный',
#  'дмитрий',
#  'коллега',
#  'анастасия',
#  'подсказала',
#  'открытый',
#  'вопрос',
#  'связать',
#  'технический',
#  'особенность',
#  'серым',
#  'готовый',
#  'буду',
#  'ответить',
#  'взять',
#  'пауза',
#  'решить',
#  'вопрос',
#  'уточнить',
#  'пожалуйста',
#  'задача',
#  'состоять',
#  'задача',
#  'общий',
#  'стоить',
#  'секунда',
#  'угу',
#  'общий',
#  'настроить',
#  'воронка',
#  'весь',
#  'мочь',
#  'сделать',
#  'сэйл',
#  'бот',
#  'очень',
#  'важный',
#  'думать',
#  'например',
#  'очень',
#  'важный',
#  'думать',
#  'например',
#  ...]

# %%
segmenter = Segmenter()
morph_vocab = MorphVocab()

emb = NewsEmbedding()
morph_tagger = NewsMorphTagger(emb)
syntax_parser = NewsSyntaxParser(emb)
ner_tagger = NewsNERTagger(emb)

names_extractor = NamesExtractor(morph_vocab)

# %%
# data['name'] = data['text_normalized'].apply(lambda x: names_extractor.extract_name(x))

# %%
data['names_extracted']=data['text_normalized'].apply(names_extractor.find)

# %%
new_cols_df = data['names_extracted'].apply(lambda x: x.fact.as_json if x else None).apply(pd.Series)

# %%
new_cols_df
# Out:
#               last     first
# 0              NaN       NaN
# 1    здравствовать       NaN
# 2           добрый       NaN
# 3              NaN  ангелина
# 4              NaN       NaN
# ..             ...       ...
# 475          повод       NaN
# 476           мочь       NaN
# 477        спасибо       NaN
# 478        спасибо       NaN
# 479        хороший       NaN
#
# [480 rows x 2 columns]

# %%
#concat new_cols_df to dataframe
data = pd.concat([data, new_cols_df], axis=1)
data
# Out:
#      dlg_id  line_n     role  \
# 0         0       0   client
# 1         0       1  manager
# 2         0       2   client
# 3         0       3  manager
# 4         0       4   client
# ..      ...     ...      ...
# 475       5     138  manager
# 476       5     139  manager
# 477       5     140   client
# 478       5     141   client
# 479       5     142  manager
#
#                                                   text  greeting  \
# 0                                                 Алло     False
# 1                                    Алло здравствуйте     False
# 2                                          Добрый день     False
# 3    Меня зовут ангелина компания диджитал бизнес з...     False
# 4                                                  Ага     False
# ..                                                 ...       ...
# 475  По поводу виджетов и с ними уже обсудите конкр...     False
# 476  Все я вам высылаю счет и с вами на связи если ...     False
# 477                                    Спасибо спасибо     False
# 478     Да да тогда созвонимся ага спасибо вам давайте     False
# 479                     Ну до свидания хорошего вечера     False
#
#      introduction  manager_name  company_name  goodbye  \
# 0           False         False         False    False
# 1           False         False         False    False
# 2           False         False         False    False
# 3           False         False         False    False
# 4           False         False         False    False
# ..            ...           ...           ...      ...
# 475         False         False         False    False
# 476         False         False         False    False
# 477         False         False         False    False
# 478         False         False         False    False
# 479         False         False         False    False
#
#                                                 tokens  \
# 0                                               [алло]
# 1                                [алло, здравствовать]
# 2                                       [добрый, день]
# 3    [звать, ангелина, компания, диджитал, бизнес, ...
# 4                                                [ага]
# ..                                                 ...
# 475  [повод, виджет, ними, обсудить, конкретно, про...
# 476  [весь, высылать, счёт, вами, связь, будут, воп...
# 477                                 [спасибо, спасибо]
# 478                 [созвонимся, ага, спасибо, давать]
# 479                         [свидание, хороший, вечер]
#
#                                        text_normalized  \
# 0                                                 алло
# 1                                   алло здравствовать
# 2                                          добрый день
# 3    звать ангелина компания диджитал бизнес звоним...
# 4                                                  ага
# ..                                                 ...
# 475        повод виджет ними обсудить конкретно продам
# 476  весь высылать счёт вами связь будут вопрос моч...
# 477                                    спасибо спасибо
# 478                      созвонимся ага спасибо давать
# 479                             свидание хороший вечер
#
#                                        names_extracted           last  \
# 0                                                 None            NaN
# 1    Match(start=5, stop=18, fact=Name(first=None, ...  здравствовать
# 2    Match(start=0, stop=6, fact=Name(first=None, l...         добрый
# 3    Match(start=6, stop=14, fact=Name(first='ангел...            NaN
# 4                                                 None            NaN
# ..                                                 ...            ...
# 475  Match(start=0, stop=5, fact=Name(first=None, l...          повод
# 476  Match(start=43, stop=47, fact=Name(first=None,...           мочь
# 477  Match(start=0, stop=7, fact=Name(first=None, l...        спасибо
# 478  Match(start=15, stop=22, fact=Name(first=None,...        спасибо
# 479  Match(start=9, stop=16, fact=Name(first=None, ...        хороший
#
#         first
# 0         NaN
# 1         NaN
# 2         NaN
# 3    ангелина
# 4         NaN
# ..        ...
# 475       NaN
# 476       NaN
# 477       NaN
# 478       NaN
# 479       NaN
#
# [480 rows x 14 columns]

# %%
# Поиск и обработка реплик приветствия

nlp = spacy.load('ru_core_news_sm', disable=["ner", "parser"])
ruler = nlp.add_pipe("entity_ruler") #назначение именнованных правил шаблонов
matcher = Matcher(nlp.vocab) #поисковик по словарю модели spacy

def add_entity(unique_ds, label):

    #Create the EntityRuler
    for ent in unique_ds:
        ruler.add_patterns([{"label": label, "pattern":ent}])
        # ruler.add_patterns([{"label": "greeting", "pattern":a}])
    return ruler

# %%
unique_gt =["Добрый день", "Здравствуйте", "здравствуйте", "Алло"]
ruler = add_entity(unique_gt, "greeting")

# %%
pattern1 =[[{'ENT_TYPE': 'greeting'}]]
matcher.add("gret1",pattern1)

# %%
pattern2 =[[{'ENT_TYPE': 'greeting'},{'ENT_TYPE': 'greeting'}]]
matcher.add("gret2",pattern2)

# %%
#names pattern

# %%
unique_names = list(data['first'].unique())[1:]

# %%
unique_names
# Out:
# ['ангелина',
#  'хирам',
#  'поле',
#  'сапаров',
#  'астана',
#  'любой',
#  'дмитрий',
#  'айдар',
#  'галочка',
#  'анастасия',
#  'амо',
#  'вячеслав',
#  'максим']

# %%
# unique_names
ruler = add_entity(unique_names, "name")

# %%
pattern3 =[[{'ENT_TYPE': 'name'}]]
matcher.add("name",pattern3)

# %%
#company pattern

business_names = ["диджитал бизнес"]
ruler = add_entity(business_names, "company")

# %%
pattern4 =[[{'ENT_TYPE': 'company'}]]
matcher.add("company",pattern4)

# %%
#goodbye pattern
goodbye = ["пока", "до свидания", "до встречи"]
ruler = add_entity(goodbye, "goodbye")

# %%
pattern5 =[[{'ENT_TYPE': 'goodbye'}]]
matcher.add("goodbye",pattern5)

# %%
pattern5_1 =[[{'ENT_TYPE': 'goodbye'}, {'ENT_TYPE': 'goodbye'}]]
matcher.add("goodbye1",pattern5_1)

# %%
def matches_in_df(matcher):
    match_list = []
    text_list = []
    ind_list = []

    for i in range(len(data["text"])):
        
        
        try:
            
            text = data["text"].iloc[i]
            doc = nlp(text)

            matches = matcher(doc)
            for match_id, start, end in matches:
                
                string_id = nlp.vocab.strings[match_id]  # Get string representation
                span = doc[start:end]  # The matched span
          #     print(match_id, string_id, start, end, span.text)
          #     print(string_id, span.text, i)
                match_list.append(string_id)
                text_list.append(span.text)
                ind_list.append(i)
          #     print(i)
        
        except:
            
            match_list.append("null")
            text_list.append("null")
            ind_list.append(i)
            pass

    df_matches = pd.DataFrame(columns =['match', 'text', 'id'])
    df_matches['match']=match_list
    df_matches['text']=text_list
    df_matches['id']=ind_list

    return df_matches

# %%
matches_in_df(matcher)
# Out:
#        match               text   id
# 0      gret1               Алло    0
# 1      gret1               Алло    1
# 2      gret2  Алло здравствуйте    1
# 3      gret1       здравствуйте    1
# 4      gret1             Добрый    2
# ..       ...                ...  ...
# 63     gret1               Алло  455
# 64      name            дмитрий  472
# 65   goodbye                 до  479
# 66  goodbye1        до свидания  479
# 67   goodbye           свидания  479
#
# [68 rows x 3 columns]

# %%
index_greet = matches_in_df(matcher)[(matches_in_df(matcher)['match']=='gret1') | (matches_in_df(matcher)['match']=='gret2') ]['text']

# %%
index_name = matches_in_df(matcher)[(matches_in_df(matcher)['match']=='name')]['text']

# %%
index_company = matches_in_df(matcher)[(matches_in_df(matcher)['match']=='company')]['text']

# %%
list(index_greet.unique())
# Out:
# ['Алло',
#  'Алло здравствуйте',
#  'здравствуйте',
#  'Добрый',
#  'Добрый день',
#  'день',
#  'Здравствуйте']

# %%
list(index_name.unique())
# Out:
# ['ангелина',
#  'астана',
#  'дмитрий',
#  'максим',
#  'анастасия',
#  'амо',
#  'айдар',
#  'любой',
#  'вячеслав']

# %%
list(index_company.unique())
# Out:
# ['диджитал', 'бизнес']

# %%
index_goodbye = matches_in_df(matcher)[(matches_in_df(matcher)['match']=='goodbye') | (matches_in_df(matcher)['match']=='goodbye1') ]['text']

# %%
list(index_goodbye.unique())
# Out:
# ['до', 'до свидания', 'свидания', 'пока']

# %%
#Извлекать реплики с приветствием – где менеджер поздоровался.
for i in range(len(txt)):
    if any(txt[i].find(x) != -1 for x in list(index_greet.unique())):
        data['greeting'][i] = 1
    else:
        data['greeting'][i] = 0

# %%
#проверка строк где поздровались
data[data['greeting']==1]
# Out:
#      dlg_id  line_n     role  \
# 0         0       0   client
# 1         0       1  manager
# 2         0       2   client
# 80        0      80   client
# 109       1       0   client
# 110       1       1  manager
# 131       1      22   client
# 164       2       0   client
# 165       2       1   client
# 166       2       2  manager
# 249       3       0   client
# 250       3       1  manager
# 251       3       2  manager
# 281       3      32   client
# 282       3      33  manager
# 302       4       0   client
# 303       4       1   client
# 304       4       2   client
# 337       5       0   client
# 358       5      21   client
# 434       5      97  manager
# 455       5     118   client
#
#                                                   text  greeting  \
# 0                                                 Алло      True
# 1                                    Алло здравствуйте      True
# 2                                          Добрый день      True
# 80                                                Алло      True
# 109                Да здравствуйте когда заканчивается      True
# 110                                  Алло здравствуйте      True
# 131                                               Алло      True
# 164                                               Алло      True
# 165                                       Здравствуйте      True
# 166                                  Алло здравствуйте      True
# 249                                        Добрый день      True
# 250                           Алло дмитрий добрый день      True
# 251  Добрый меня максим зовут компания китобизнес у...      True
# 281                  Если это за деньги в любом случае      True
# 282  Да нет конечно не сложно да ну смотрите да мы ...      True
# 302                                               Алло      True
# 303                                               Алло      True
# 304                                             Добрый      True
# 337                                               Алло      True
# 358  Да да да здравствуйте анастасия меня слышно да...      True
# 434  Вот то у нас прописан договор в котором пропис...      True
# 455                                               Алло      True
#
#      introduction  manager_name  company_name  goodbye  \
# 0           False         False         False    False
# 1           False         False         False    False
# 2           False         False         False    False
# 80          False         False         False    False
# 109         False         False         False    False
# 110         False         False         False    False
# 131         False         False         False    False
# 164         False         False         False    False
# 165         False         False         False    False
# 166         False         False         False    False
# 249         False         False         False    False
# 250         False         False         False    False
# 251         False         False         False    False
# 281         False         False         False    False
# 282         False         False         False    False
# 302         False         False         False    False
# 303         False         False         False    False
# 304         False         False         False    False
# 337         False         False         False    False
# 358         False         False         False    False
# 434         False         False         False    False
# 455         False         False         False    False
#
#                                                 tokens  \
# 0                                               [алло]
# 1                                [алло, здравствовать]
# 2                                       [добрый, день]
# 80                                              [алло]
# 109                     [здравствовать, заканчиваться]
# 110                              [алло, здравствовать]
# 131                                             [алло]
# 164                                             [алло]
# 165                                    [здравствовать]
# 166                              [алло, здравствовать]
# 249                                     [добрый, день]
# 250                      [алло, дмитрий, добрый, день]
# 251  [добрый, максим, звать, компания, китобизнес, ...
# 281                       [это, деньга, любой, случай]
# 282  [сложный, смотреть, общий, целое, начать, сотр...
# 302                                             [алло]
# 303                                             [алло]
# 304                                           [добрый]
# 337                                             [алло]
# 358                [здравствовать, анастасия, слышный]
# 434  [прописать, договор, котором, прописать, отвеч...
# 455                                             [алло]
#
#                                        text_normalized  \
# 0                                                 алло
# 1                                   алло здравствовать
# 2                                          добрый день
# 80                                                алло
# 109                        здравствовать заканчиваться
# 110                                 алло здравствовать
# 131                                               алло
# 164                                               алло
# 165                                      здравствовать
# 166                                 алло здравствовать
# 249                                        добрый день
# 250                           алло дмитрий добрый день
# 251  добрый максим звать компания китобизнес удобны...
# 281                            это деньга любой случай
# 282  сложный смотреть общий целое начать сотрудниче...
# 302                                               алло
# 303                                               алло
# 304                                             добрый
# 337                                               алло
# 358                    здравствовать анастасия слышный
# 434  прописать договор котором прописать отвечать 2...
# 455                                               алло
#
#                                        names_extracted           last    first
# 0                                                 None            NaN      NaN
# 1    Match(start=5, stop=18, fact=Name(first=None, ...  здравствовать      NaN
# 2    Match(start=0, stop=6, fact=Name(first=None, l...         добрый      NaN
# 80                                                None            NaN      NaN
# 109  Match(start=0, stop=13, fact=Name(first=None, ...  здравствовать      NaN
# 110  Match(start=5, stop=18, fact=Name(first=None, ...  здравствовать      NaN
# 131                                               None            NaN      NaN
# 164                                               None            NaN      NaN
# 165  Match(start=0, stop=13, fact=Name(first=None, ...  здравствовать      NaN
# 166  Match(start=5, stop=18, fact=Name(first=None, ...  здравствовать      NaN
# 249  Match(start=0, stop=6, fact=Name(first=None, l...         добрый      NaN
# 250  Match(start=5, stop=12, fact=Name(first='дмитр...            NaN  дмитрий
# 251  Match(start=0, stop=6, fact=Name(first=None, l...         добрый      NaN
# 281  Match(start=11, stop=16, fact=Name(first='любо...            NaN    любой
# 282  Match(start=0, stop=7, fact=Name(first=None, l...        сложный      NaN
# 302                                               None            NaN      NaN
# 303                                               None            NaN      NaN
# 304  Match(start=0, stop=6, fact=Name(first=None, l...         добрый      NaN
# 337                                               None            NaN      NaN
# 358  Match(start=0, stop=13, fact=Name(first=None, ...  здравствовать      NaN
# 434  Match(start=18, stop=25, fact=Name(first=None,...        котором      NaN
# 455                                               None            NaN      NaN

# %%
# Извлекать реплики с приветствием – где менеджер поздоровался.

# %%
# Извлекать реплики, где менеджер представил себя.

# %%
for i in range(len(txt)):
    if any(txt[i].find(x) != -1 for x in list(index_name.unique())):
        data['manager_name'][i] = 1
    else:
        data['manager_name'][i] = 0

# %%
#проверка строк где менеджер представился
data[data['manager_name']==1]['first']
# Out:
# 3       ангелина
# 26           NaN
# 111     ангелина
# 159          NaN
# 167     ангелина
# 229       астана
# 250      дмитрий
# 251          NaN
# 253      дмитрий
# 282          NaN
# 285          NaN
# 319        айдар
# 338    анастасия
# 346          NaN
# 358          NaN
# 364          NaN
# 375          NaN
# 410          амо
# 438     вячеслав
# 444       максим
# 448        любой
# 472      дмитрий
# Name: first, dtype: object

# %%
data
# Out:
#      dlg_id  line_n     role  \
# 0         0       0   client
# 1         0       1  manager
# 2         0       2   client
# 3         0       3  manager
# 4         0       4   client
# ..      ...     ...      ...
# 475       5     138  manager
# 476       5     139  manager
# 477       5     140   client
# 478       5     141   client
# 479       5     142  manager
#
#                                                   text  greeting  \
# 0                                                 Алло      True
# 1                                    Алло здравствуйте      True
# 2                                          Добрый день      True
# 3    Меня зовут ангелина компания диджитал бизнес з...     False
# 4                                                  Ага     False
# ..                                                 ...       ...
# 475  По поводу виджетов и с ними уже обсудите конкр...     False
# 476  Все я вам высылаю счет и с вами на связи если ...     False
# 477                                    Спасибо спасибо     False
# 478     Да да тогда созвонимся ага спасибо вам давайте     False
# 479                     Ну до свидания хорошего вечера     False
#
#      introduction  manager_name  company_name  goodbye  \
# 0           False         False         False    False
# 1           False         False         False    False
# 2           False         False         False    False
# 3           False          True         False    False
# 4           False         False         False    False
# ..            ...           ...           ...      ...
# 475         False         False         False    False
# 476         False         False         False    False
# 477         False         False         False    False
# 478         False         False         False    False
# 479         False         False         False    False
#
#                                                 tokens  \
# 0                                               [алло]
# 1                                [алло, здравствовать]
# 2                                       [добрый, день]
# 3    [звать, ангелина, компания, диджитал, бизнес, ...
# 4                                                [ага]
# ..                                                 ...
# 475  [повод, виджет, ними, обсудить, конкретно, про...
# 476  [весь, высылать, счёт, вами, связь, будут, воп...
# 477                                 [спасибо, спасибо]
# 478                 [созвонимся, ага, спасибо, давать]
# 479                         [свидание, хороший, вечер]
#
#                                        text_normalized  \
# 0                                                 алло
# 1                                   алло здравствовать
# 2                                          добрый день
# 3    звать ангелина компания диджитал бизнес звоним...
# 4                                                  ага
# ..                                                 ...
# 475        повод виджет ними обсудить конкретно продам
# 476  весь высылать счёт вами связь будут вопрос моч...
# 477                                    спасибо спасибо
# 478                      созвонимся ага спасибо давать
# 479                             свидание хороший вечер
#
#                                        names_extracted           last  \
# 0                                                 None            NaN
# 1    Match(start=5, stop=18, fact=Name(first=None, ...  здравствовать
# 2    Match(start=0, stop=6, fact=Name(first=None, l...         добрый
# 3    Match(start=6, stop=14, fact=Name(first='ангел...            NaN
# 4                                                 None            NaN
# ..                                                 ...            ...
# 475  Match(start=0, stop=5, fact=Name(first=None, l...          повод
# 476  Match(start=43, stop=47, fact=Name(first=None,...           мочь
# 477  Match(start=0, stop=7, fact=Name(first=None, l...        спасибо
# 478  Match(start=15, stop=22, fact=Name(first=None,...        спасибо
# 479  Match(start=9, stop=16, fact=Name(first=None, ...        хороший
#
#         first
# 0         NaN
# 1         NaN
# 2         NaN
# 3    ангелина
# 4         NaN
# ..        ...
# 475       NaN
# 476       NaN
# 477       NaN
# 478       NaN
# 479       NaN
#
# [480 rows x 14 columns]

# %%
#Извлекать реплики с company – где менеджер представил компанию.
for i in range(len(txt)):
    if any(txt[i].find(x) != -1 for x in list(index_company.unique())):
        data['company_name'][i] = 1
    else:
        data['company_name'][i] = 0

# %%
#проверка строк где менеджер представил компанию
data[data['company_name']==1]['text']
# Out:
# 3      Меня зовут ангелина компания диджитал бизнес з...
# 111    Меня зовут ангелина компания диджитал бизнес з...
# 167    Меня зовут ангелина компания диджитал бизнес з...
# 177                                      Диджитал бизнес
# 178                                Здесь же это у бизнес
# 184    Вот и смотрите на счет кэшбэка то что у вас кэ...
# 235    Не перепутала оставлю тогда на ватсап хорошо а...
# 251    Добрый меня максим зовут компания китобизнес у...
# 268    Так а вот подскажите пожалуйста может быть про...
# 282    Да нет конечно не сложно да ну смотрите да мы ...
# 285    А самого внедрения процесса ну я я бы вам реко...
# 373    Конкретно под ваш бизнес разговаривать и вам у...
# 421    А там раз в неделю будет как то диагностироват...
# 444    Вот и вам с вами свяжется максим он отвечает у...
# 447    Вот и после этого он уже вам даст рекомендации...
# 448    То есть это уже будете обсуждать с ним и если ...
# Name: text, dtype: object

# %%
#Извлекать реплики с goodbye – где менеджер прощался.
for i in range(len(txt)):
    if any(txt[i].find(x) != -1 for x in list(index_goodbye.unique())):
        data['goodbye'][i] = 1
    else:
        data['goodbye'][i] = 0

# %%
#проверка строк где менеджер прощался
data[data['goodbye']==1]['text']
# Out:
# 7      Как как бы уже до этого момента работаем все у...
# 10     Да на выбор я уже не обращаю внимание я уже до...
# 23     Незначительная но бесплатная и покажите свою к...
# 26     Ну лояльности спрашивается 2 месяц не показыва...
# 30     А как будет недостаточно хорошие качественные ...
# 35     Слушайте очень сложно сказать потому что видже...
# 59     По какой причине я должен принять решение в ва...
# 68     Ну не факт что вы не можете получить допустим ...
# 84                                        Решать договор
# 95     Ну просто подумайте подумайте вашей командой к...
# 96     Потому что это ну вот эти звонки за месяц до о...
# 97     Мне конечно интересно какая у вас конверсия та...
# 108                           Всего хорошего до свидания
# 123                     Мне пока больше не надо наверное
# 125    65 а нет не там еще 1 2 3 4 5 нет правильно ну...
# 129    564 р тогда такой вопрос и это допустим сейчас...
# 133    Сейчас прямо здесь скажите пожалуйста в пользо...
# 163                                          До свидания
# 169                           Ну разговаривать удобно да
# 170    Удобно вам сейчас говорить что я вам так расск...
# 186    Контроль например отказов то есть только для в...
# 236    Угу у нас еще неделя но давайте до среды решим...
# 250                             Алло дмитрий добрый день
# 251    Добрый меня максим зовут компания китобизнес у...
# 252                                            Да удобно
# 266    Да абсолютно все то есть это единое такое окно...
# 273    Транспортная компания хорошо а у вас уже вот в...
# 275    Да но если мы будем прям настраивать вам серым...
# 282    Да нет конечно не сложно да ну смотрите да мы ...
# 285    А самого внедрения процесса ну я я бы вам реко...
# 296                 А скажите когда удобно так и наберем
# 300    Угу все хорошо да понедельника тогда всего доб...
# 301                                       Да до свидания
# 313    Понятно а оплата на сколько должна быть на это...
# 318    Хорошо и вы имеете ввиду доработку какую это к...
# 319    А вот а ну вот помните айдар вам не подходило ...
# 329    А если про саму форму ну то есть вы получите т...
# 335    Во вторник все ну с вами да тогда до вторника ...
# 336                                   Угу да до свидания
# 351    Да понимаю вас смотрите но вы вы же понимаете ...
# 363                           Вот и какой тариф подойдет
# 364    Нет смотрите мне я понимаю что там что то подк...
# 434    Вот то у нас прописан договор в котором пропис...
# 447    Вот и после этого он уже вам даст рекомендации...
# 452    Ну вы тогда высылайте тогда договор и высылайт...
# 456    Ну вот смотрите сегодня уже вряд ли потому что...
# 479                       Ну до свидания хорошего вечера
# Name: text, dtype: object

# %%
# создать столбец с названием culture, в котором 1 если в строке greeting 1 и в строке goodbye 1, иначе 0
data['culture'] = data['greeting'] + data['goodbye']
data['culture'] = data['culture'].apply(lambda x: 1 if x == 2 else 0)

# %%
data
# Out:
#      dlg_id  line_n     role  \
# 0         0       0   client
# 1         0       1  manager
# 2         0       2   client
# 3         0       3  manager
# 4         0       4   client
# ..      ...     ...      ...
# 475       5     138  manager
# 476       5     139  manager
# 477       5     140   client
# 478       5     141   client
# 479       5     142  manager
#
#                                                   text  greeting  \
# 0                                                 Алло      True
# 1                                    Алло здравствуйте      True
# 2                                          Добрый день      True
# 3    Меня зовут ангелина компания диджитал бизнес з...     False
# 4                                                  Ага     False
# ..                                                 ...       ...
# 475  По поводу виджетов и с ними уже обсудите конкр...     False
# 476  Все я вам высылаю счет и с вами на связи если ...     False
# 477                                    Спасибо спасибо     False
# 478     Да да тогда созвонимся ага спасибо вам давайте     False
# 479                     Ну до свидания хорошего вечера     False
#
#      introduction  manager_name  company_name  goodbye  \
# 0           False         False         False    False
# 1           False         False         False    False
# 2           False         False         False    False
# 3           False          True          True    False
# 4           False         False         False    False
# ..            ...           ...           ...      ...
# 475         False         False         False    False
# 476         False         False         False    False
# 477         False         False         False    False
# 478         False         False         False    False
# 479         False         False         False     True
#
#                                                 tokens  \
# 0                                               [алло]
# 1                                [алло, здравствовать]
# 2                                       [добрый, день]
# 3    [звать, ангелина, компания, диджитал, бизнес, ...
# 4                                                [ага]
# ..                                                 ...
# 475  [повод, виджет, ними, обсудить, конкретно, про...
# 476  [весь, высылать, счёт, вами, связь, будут, воп...
# 477                                 [спасибо, спасибо]
# 478                 [созвонимся, ага, спасибо, давать]
# 479                         [свидание, хороший, вечер]
#
#                                        text_normalized  \
# 0                                                 алло
# 1                                   алло здравствовать
# 2                                          добрый день
# 3    звать ангелина компания диджитал бизнес звоним...
# 4                                                  ага
# ..                                                 ...
# 475        повод виджет ними обсудить конкретно продам
# 476  весь высылать счёт вами связь будут вопрос моч...
# 477                                    спасибо спасибо
# 478                      созвонимся ага спасибо давать
# 479                             свидание хороший вечер
#
#                                        names_extracted           last  \
# 0                                                 None            NaN
# 1    Match(start=5, stop=18, fact=Name(first=None, ...  здравствовать
# 2    Match(start=0, stop=6, fact=Name(first=None, l...         добрый
# 3    Match(start=6, stop=14, fact=Name(first='ангел...            NaN
# 4                                                 None            NaN
# ..                                                 ...            ...
# 475  Match(start=0, stop=5, fact=Name(first=None, l...          повод
# 476  Match(start=43, stop=47, fact=Name(first=None,...           мочь
# 477  Match(start=0, stop=7, fact=Name(first=None, l...        спасибо
# 478  Match(start=15, stop=22, fact=Name(first=None,...        спасибо
# 479  Match(start=9, stop=16, fact=Name(first=None, ...        хороший
#
#         first  culture
# 0         NaN        0
# 1         NaN        0
# 2         NaN        0
# 3    ангелина        0
# 4         NaN        0
# ..        ...      ...
# 475       NaN        0
# 476       NaN        0
# 477       NaN        0
# 478       NaN        0
# 479       NaN        0
#
# [480 rows x 15 columns]

# %%
"git init
# Out:
#   File "<ipython-input-174-f188d5ac1197>", line 1
#     git init
#         ^
# SyntaxError: invalid syntax

# %%
git init
git add README.md
git commit -m "first commit"
git branch -M main
git remote add origin https://github.com/Subzero322/test.git
git push -u origin main
# Out:
#   File "<ipython-input-173-a0bc2b1db054>", line 1
#     git init
#         ^
# SyntaxError: invalid syntax
